# %% [markdown]
# <a href="https://colab.research.google.com/github/majorow/people_tracking/blob/main/Classify_people.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import numpy as np

# %%
path = '/content/drive/MyDrive/trainee/dataset-cls/'
model = YOLO('yolov8s-cls.pt')
model.train(data=path, epochs=30)
# Out:
# ...
#   0%|          | 0.00/12.2M [00:00<?, ?B/s]
# Ultralytics YOLOv8.0.53 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
path = '/content/drive/MyDrive/trainee/dataset-cls/'
path1 = path + 'train/builder/'
model = YOLO(path + 'best-cls1s30.pt')
res = model.predict(source=path1)
# Out:
# image 1/152 /content/drive/MyDrive/trainee/dataset-cls/train/builder/1002.jpg: 224x224 helmet 0.71, uniform 0.18, builder 0.11, person 0.00, 5.5ms
# image 2/152 /content/drive/MyDrive/trainee/dataset-cls/train/builder/1004.jpg: 224x224 helmet 0.91, uniform 0.06, builder 0.03, person 0.00, 8.2ms
# image 3/152 /content/drive/MyDrive/trainee/dataset-cls/train/builder/1008.jpg: 224x224 helmet 0.61, uniform 0.29, builder 0.10, person 0.00, 3.9ms
# image 4/152 /content/drive/MyDrive/trainee/dataset-cls/train/builder/1010.jpg: 224x224 uniform 0.47, helmet 0.43, builder 0.10, person 0.00, 4.3ms
# image 5/152 /content/drive/MyDrive/trainee/dataset-cls/train/builder/1014.jpg: 224x224 helmet 0.50, uniform 0.40, builder 0.10, person 0.00, 3.9ms
# image 6/152 /content/drive/MyDrive/trainee/dataset-cls/train/builder/1018.jpg: 224x224 helmet 0.60, uniform 0.28, builder 0.12, person 0.00, 4.4ms
# ...

# %%
np_res = np.empty((0, 4))
for result in res:
  temp = result.probs.cpu().numpy()
  np_res = np.vstack((np_res, temp))
_, np_prob = np.unique(np.argmax(np_res, axis=1), return_counts=True)
np_prob
# Out:
# array([81, 36, 11, 24])
